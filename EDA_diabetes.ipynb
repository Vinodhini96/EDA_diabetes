# %% [markdown]
# # Exploratory Data Analysis
# ## diabetes.csv file
# by Vinodhini Rajamanickam

# %% [markdown]
# ## importing pandas

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## reading csv file

# %%
diabetes_data= pd.read_csv("diabetes (1).csv")

# %% [markdown]
# ## printing data

# %%
diabetes_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ## getting summary of the data

# %%
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ## checking if any null value is present

# %%
diabetes_data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## printing all the columns

# %%
diabetes_data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# ## printing unique age

# %%
diabetes_data["Age"].unique()
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 34, 57, 59, 51, 27, 41, 43,
#        22, 38, 60, 28, 45, 35, 46, 56, 37, 48, 40, 25, 24, 58, 42, 44, 39,
#        36, 23, 61, 69, 62, 55, 65, 47, 52, 66, 49, 63, 67, 72, 81, 64, 70,
#        68], dtype=int64)

# %% [markdown]
# ## checking people whose age is less than 30

# %%
diabetes_data.query("`Age` <30")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 20             3      126             88             41      235  39.3
# 23             9      119             80             35        0  29.0
# ..           ...      ...            ...            ...      ...   ...
# 753            0      181             88             44      510  43.3
# 758            1      106             76              0        0  37.5
# 760            2       88             58             26       16  28.4
# 764            2      122             70             27        0  36.8
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# ...

# %% [markdown]
# ## checking unique pregnancy values

# %%
diabetes_data["Pregnancies"].unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14],
#       dtype=int64)

# %% [markdown]
# ## checking people whose age is less than 30 and have pregnancies more than 3

# %%
diabetes_data.query(("`Age`<30 and `Pregnancies` >3"))
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 7             10      115              0              0        0  35.3
# 23             9      119             80             35        0  29.0
# 33             6       92             92              0        0  19.9
# 49             7      105              0              0        0   0.0
# 69             4      146             85             27      100  28.9
# ..           ...      ...            ...            ...      ...   ...
# 704            4      110             76             20      100  28.4
# 705            6       80             80             36        0  39.8
# 731            8      120             86              0        0  28.4
# 735            4       95             60             32        0  35.4
# 750            4      136             70              0        0  31.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 7                       0.134   29        0
# ...

# %% [markdown]
# ## person age less than 30 and overweight

# %%
diabetes_data.query(("`Age`<30 and `BMI` > 24.9"))
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 20             3      126             88             41      235  39.3
# 23             9      119             80             35        0  29.0
# ..           ...      ...            ...            ...      ...   ...
# 753            0      181             88             44      510  43.3
# 758            1      106             76              0        0  37.5
# 760            2       88             58             26       16  28.4
# 764            2      122             70             27        0  36.8
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# ...

# %% [markdown]
# ## person with age less than 30 and is underweight

# %%
diabetes_data.query(("`Age` <30 and `BMI`< 18.5"))
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 49             7      105              0              0        0   0.0
# 60             2       84              0              0        0   0.0
# 81             2       74              0              0        0   0.0
# 145            0      102             75             23        0   0.0
# 239            0      104             76              0        0  18.4
# 371            0      118             64             23       89   0.0
# 418            1       83             68              0        0  18.2
# 426            0       94              0              0        0   0.0
# 438            1       97             70             15        0  18.2
# 494            3       80              0              0        0   0.0
# 522            6      114              0              0        0   0.0
# 526            1       97             64             19       82  18.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %% [markdown]
# ## peope between age 30-50  and underwight

# %%
diabetes_data.query(("`Age` >30 and `Age` <50 and `BMI` <18.5"))
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %% [markdown]
# ## people between age 30-50 and overweight

# %%
diabetes_data.query(("`Age` >30 and `Age` <50 and `BMI` >24.9"))
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 4              0      137             40             35      168  43.1
# 11            10      168             74              0        0  38.0
# 15             7      100              0              0        0  30.0
# 16             0      118             84             47      230  45.8
# ..           ...      ...            ...            ...      ...   ...
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 756            7      137             90             41        0  32.0
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %% [markdown]
# ## age more than 50 and underweight

# %%
diabetes_data.query(("`Age` >50 and `BMI` <18.4 "))
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 9              8      125             96              0        0  0.0
# 684            5      136             82              0        0  0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 9                       0.232   54        1
# 684                     0.640   69        0

# %% [markdown]
# ## age more than 50 and overweight

# %%
diabetes_data.query(("`Age` >50 and `BMI` <24.9 "))
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 9              8      125             96              0        0   0.0
# 28            13      145             82             19      110  22.2
# 93             4      134             72              0        0  23.8
# 140            3      128             78              0        0  21.1
# 294            0      161             50              0        0  21.9
# 299            8      112             72              0        0  23.6
# 319            6      194             78              0        0  23.5
# 401            6      137             61              0        0  24.2
# 453            2      119              0              0        0  19.6
# 512            9       91             68              0        0  24.2
# 519            6      129             90              7      326  19.6
# 537            0       57             60              0        0  21.7
# ...

# %%
a = diabetes_data[["Age", "BMI"]]
a
# Out:
#      Age   BMI
# 0     50  33.6
# 1     31  26.6
# 2     32  23.3
# 3     21  28.1
# 4     33  43.1
# ..   ...   ...
# 763   63  32.9
# 764   27  36.8
# 765   30  26.2
# 766   47  30.1
# 767   23  30.4
#
# [768 rows x 2 columns]

# %%
sns.relplot(data =a, x = "Age", y = "BMI")

# %% [markdown]
# ## checking columns pregnanicies and BMI

# %%
x =diabetes_data[['Pregnancies', 'BMI']]
x
# Out:
#      Pregnancies   BMI
# 0              6  33.6
# 1              1  26.6
# 2              8  23.3
# 3              1  28.1
# 4              0  43.1
# ..           ...   ...
# 763           10  32.9
# 764            2  36.8
# 765            5  26.2
# 766            1  30.1
# 767            1  30.4
#
# [768 rows x 2 columns]

# %%
sns.relplot(data= x, x = "Pregnancies", y = "BMI")

# %%
b = diabetes_data[['Age', 'BloodPressure', 'Glucose']]
b
# Out:
#      Age  BloodPressure  Glucose
# 0     50             72      148
# 1     31             66       85
# 2     32             64      183
# 3     21             66       89
# 4     33             40      137
# ..   ...            ...      ...
# 763   63             76      101
# 764   27             70      122
# 765   30             72      121
# 766   47             60      126
# 767   23             70       93
#
# [768 rows x 3 columns]

# %% [markdown]
# ## relation plot on between blood pressure and age

# %%
sns.relplot(data =b, x = "BloodPressure", y ="Age")

# %% [markdown]
# ## relation plot between insulin and glucose

# %%
sns.relplot(data= diabetes_data, x = "Insulin", y = "Glucose")
